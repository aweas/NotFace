# %% [markdown]
# # Learns on whole faces, finds face by moving window

# %%
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import scipy.misc
import skimage.transform
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.feature_extraction import image
from PIL import Image
import threading
import time
import tqdm
# import cv2
from scipy import ndimage

# %% [markdown]
# # Classes

# %%
class FaceFinder:
    def __init__(self):
        self.img = None
        self.img_not_processed = None
        self.img_orig = None
        self.occurences_map = None
        self.patches = []
        self.preds = None
        self.proba = None

    def process_photo(self, img_name, patch_size=64, stride=1/2):
        self.patches = []
        self.img = plt.imread(img_name)
        self.img_not_processed = self.img.copy()
        self.img = preprocess_image(self.img)
        self.img_orig = self.img.copy()
        self.occurences_map = np.zeros(shape=(self.img.shape[0], self.img.shape[1]))
        
        self._split_pic_into_frames(size=patch_size, stride=stride)
        self._run_predictions()
        
        return self._gray_out()

    def _split_pic_into_frames(self, size, stride):
        sh_x = self.img.shape[1]
        sh_y = self.img.shape[0]
        len_x = size
        len_y = size
        stride_x = np.ceil(len_x*stride).astype(int)
        stride_y = np.ceil(len_y*stride).astype(int)

        for y in range(0, sh_y, stride_y):
            for x in range(0, sh_x, stride_x):
                patch = self.img[y:y+len_y, x:x+len_x]        
                if patch.shape[0]*patch.shape[1]!=0:
                    self.patches.append([patch, (y, x), (y+len_y, x+len_x)])

    def _rectangify_patches(self):
        columns = int(np.sqrt(len(self.preds)))

        cont = True
        while cont:
            cont = False
            for r in range(columns-1):
                for c in range(columns-1):
                    if self.preds[r*columns+c] == 0:
                        LD = self.preds[(r+1)*columns+c-1]
                        SD = self.preds[(r+1)*columns+c]
                        RD = self.preds[(r+1)*columns+c+1]
                        L = self.preds[r*columns+c-1]
                        R = self.preds[r*columns+c+1]
                        LG = self.preds[(r-1)*columns+c-1]
                        SG = self.preds[(r-1)*columns+c]
                        RG = self.preds[(r-1)*columns+c+1]

                        answ = L*LD*SD + SD*RD*R + R*RG*SG + SG*LG*L

                        if answ >= 1:
                            cont = True
                            self.preds[r*columns+c] = 1

    def _gray_out(self):
        coord_start = np.array(self.patches)[:, 1]
        coord_end = np.array(self.patches)[:, 2]

        self.img.setflags(write=1)
        print('Patches: %i' % len(self.patches))
        for start, end, pred in zip(coord_start, coord_end, self.preds):
            if pred==1:
                self.occurences_map[max(0, start[0]):end[0], max(0, start[1]):end[1]] += 1

        for start, end, pred, proba in zip(coord_start, coord_end, self.preds, self.proba):
            if pred == 1:        
                weight = (proba-1/2)*2
                addition = int(255*weight)/self.occurences_map[max(0, start[0]):end[0], max(0, start[1]):end[1]]            
                added = (self.img_not_processed[max(0, start[0]):end[0], max(0, start[1]):end[1]][:, :, 1].astype(np.float64) + addition)
                added = np.floor(added/255)*255+(1-np.floor(added/255))*added
                self.debug = added

                self.img_not_processed[max(0, start[0]):end[0], max(0, start[1]):end[1]][:, :, 1] = added.astype(np.uint8)

        return self.img, self.img_not_processed

    def _run_predictions(self):
        a = skimage.transform.resize(self.patches[0][0], shape).reshape((1, *shape))
        for i in self.patches[1:]:
            a = np.vstack((a, skimage.transform.resize(i[0], shape).reshape((1, *shape))))
        self.proba = np.array(predict_proba(a, sess))[:, 1]
        self.preds = [round(i) for i in self.proba]

# %% [markdown]
# # Model variables

# %%
epochs = 5
shape = (64, 64, 3)
face_training_location = "../Datasets/Faces_training"
notFace_training_location = "../Datasets/NotFaces"
Bush_location = "../Datasets/George_W_Bush"

# %% [markdown]
# ## Prepare data

# %%
def preprocess_image(img):
#     v = np.median(img)

    # apply automatic Canny edge detection using the computed median
#     lower = int(max(0, (1.0 - 0.33) * v))
#     upper = int(min(255, (1.0 + 0.8) * v))
#     img = cv2.Canny(img, lower, upper)

#     R = img[:, :][:, :, 0]
#     G = img[:, :][:, :, 1]
#     B = img[:, :][:, :, 2]
#     img = R * 299. / 1000 + G * 587. / 1000 + B * 114. / 1000
    
#     img = ndimage.gaussian_filter(img, 3)
#     img = img - lowpass
    return img

# %%
def enhance_faces(images):
    res = []
    for i in images:
        res.append(i)
        res.append(skimage.transform.rotate(i, 15))
        res.append(skimage.transform.rotate(i, -15))
          
    return res

# %%
def split_pic(img):
#     img = preprocess_image(img)
    face = []
    background = []
    
    img_shape = 256
    
    length = 64 
    stride = 64

    img = skimage.transform.resize(img, (img_shape, img_shape)) 
    
    for y_coord in range(0, img_shape, stride):
        for x_coord in range(0, img_shape, stride):
            patch = img[y_coord:y_coord+length, x_coord:x_coord+length]
            if y_coord>=64 and y_coord+length<=192 and x_coord>=64 and x_coord+length<=192:
                pass
            else:
                background.append(patch)
    face.append(skimage.transform.resize(img[64:192, 64:192], shape))
    
    return face, background

# %%
def readRandomNonFace(not_face_list):
    index = int(np.random.random(1)*len(not_face_list))
    x = plt.imread(not_face_list[index])
    while(len(x.shape) != 3):
        index = int(np.random.random(1)*len(not_face_list))
        x = plt.imread(not_face_list[index])    
    return x

# %%
def prepare_data(face_list, not_face_list, resize_size=shape):
    not_faces = []
    faces = []
    
    raw_face = [plt.imread(i) for i in face_list]
#     enhanced_face = enhance_faces(raw_face)       
    processed_faces = [preprocess_image(i) for i in raw_face]
    
    for i in processed_faces:
        f, b = split_pic(i)
        
        resized_not_faces = [skimage.transform.resize(img, resize_size) for img in b] 
        resized_faces = [skimage.transform.resize(img, resize_size) for img in f] 
        
        [not_faces.append(img) for img in resized_not_faces]
        [faces.append(img) for img in resized_faces]
        
    [faces.append(skimage.transform.resize(i, resize_size)) for i in processed_faces] 
    
    for i in range(len(faces)):
        raw_not_face = readRandomNonFace(not_face_list)
        processed_not_face = preprocess_image(raw_not_face)
        not_face = skimage.transform.resize(raw_not_face, resize_size)
        not_faces.append(not_face)

    y = [[1] for i in range(len(faces))]
    y.extend([[0] for i in range(len(not_faces))])
    print(np.asarray(faces).shape)
    print(np.asarray(not_faces).shape)
    return np.concatenate([faces, not_faces]), y

# %%
with open(face_training_location+'/files_list.txt') as f:
    face_files_list = f.readlines()
    
with open(notFace_training_location+'/files_list.txt') as f:
    not_face_files_list = f.readlines()
    
face_list = [f'{face_training_location}/{i.strip()}' for i in face_files_list[:100]] 
not_face_list = [f'{notFace_training_location}/{i.strip()}' for i in not_face_files_list]

# %%
X, y = prepare_data(face_list, not_face_list)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1);
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (200, 64, 64, 3)
# (1400, 64, 64, 3)

# %% [markdown]
# 870 : 6090

# %%
index = int(np.random.random(1)*len(face_list))
img = plt.imread(face_list[index])
img = preprocess_image(img)

index = int(np.random.random(1)*len(not_face_list))
img2 = plt.imread(not_face_list[index])
img2 = preprocess_image(img2)

index = int(np.random.random(1)*len(X_train))
img3 = X_train[index]

plt.figure(figsize=(16, 5))
plt.subplot(131)
plt.imshow(img, cmap='gray')
plt.title('Face')
plt.subplot(132)
plt.imshow(img2, cmap='gray')
plt.title('Not face')
plt.subplot(133)
plt.imshow(img3, cmap='gray')
plt.title(f'Training: {"Face" if y_train[index] == [1] else "Not face"}')
plt.show()

# %% [markdown]
# # Craft and fit model

# %% [markdown]
# ## Queue-based network

# %%
def architecture(inputs):
    inputs = tf.cast(inputs, tf.float32)
    
    # ARCHITECTURE
    with tf.name_scope("convolutional"):
        conv1 = tf.layers.conv2d(
                    inputs=inputs,
                    filters=32,
                    kernel_size=3,
                    padding='same',
                    activation=tf.nn.relu)
        pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2)

        conv2 = tf.layers.conv2d(
                    inputs=pool1,
                    filters=32,
                    kernel_size=3,
                    padding='same',
                    activation=tf.nn.relu)
        pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=2, strides=2)

        conv3 = tf.layers.conv2d(
                    inputs=pool2,
                    filters=64,
                    kernel_size=3,
                    padding='same',
                    activation=tf.nn.relu)
        pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2)   
        flatten = tf.reshape(pool3, [-1, int((shape[0]/8)*(shape[1]/8)*64)])  

    with tf.name_scope("dense"):
        dense1 = tf.layers.dense(
                    inputs=flatten,
                    units=512)
        dense1_batch = tf.layers.batch_normalization(dense1, training=True)
        dense1_relu = tf.nn.relu(dense1_batch)

        dense2 = tf.layers.dense(
                    inputs=dense1_relu,
                    units=256,
                    activation=tf.nn.relu)

        dense3 = tf.layers.dense(
                    inputs=dense2,
                    units=128)
        dense3_batch = tf.layers.batch_normalization(dense3, training=True)
        dense3_relu = tf.nn.relu(dense3_batch)

        dense4 = tf.layers.dense(
                    inputs=dense3_relu,
                    units=64,
                    activation=tf.nn.relu)

    with tf.name_scope("logits"):
        logits = tf.layers.dense(inputs=dense4, units=2)
    return logits

# %%
def predict_proba(X, sess):
    pred_x = tf.convert_to_tensor(X, dtype=np.float32)

    with sess.as_default():
        with tf.variable_scope("DNN", reuse=True) as scope:
            logits = architecture(pred_x)
            predictions = tf.nn.softmax(logits)
    
        return predictions.eval()

def predict(X, sess):
    result = predict_proba(X, sess)
    return np.argmax(result, axis=1)

# %%
def calculate_acc(predictions, y):
    all_true = 0
    true_positives = 0
    false_negatives = 0
    all_positives = 0
    false_positives = 0
    
    for i in range(len(predictions)):
        pos = predictions[i] == 1
        tr = [predictions[i]] == y[i]
        
        if tr:
            all_true += 1          
            if pos:
                true_positives += 1
        if not tr:
            if not pos:
                false_negatives += 1
            if pos:
                false_positives += 1
            
    result = {'acc': 0, 'precision': 0, 'recall': 0, 'sum': all_true, 'all': len(y)}
    result['acc'] = all_true/len(y)
    result['recall'] = true_positives/(true_positives+false_negatives)
    result['precision'] = true_positives/(true_positives + false_positives)
    
    return result

# %%
def evaluate(X, y, sess):
    n_iterations = int(np.ceil(len(X) / 64))
    predictions = []
    
    for i in range(n_iterations):
        predictions += predict(X[i*64:(i+1)*64], sess).tolist()
        
    result = calculate_acc(predictions, y)
            
    return result

# %%
def fit(X, y, X_test, y_test, epoch_num=5):
    coord = tf.train.Coordinator()
    n_iterations = int(np.ceil(len(X) / 64))
    
    def next_train_batch(X, y):
        batch_x = tf.constant(X, dtype=tf.float32, shape=(len(X), *shape))
        batch_y = tf.constant(y, dtype=tf.int32, shape=[len(X)])

        return [batch_x, batch_y]
    
    with tf.name_scope('train_input'):
        batch_x, batch_y = tf.train.shuffle_batch(
            next_train_batch(X, y),
            enqueue_many=True,
            batch_size=64,
            capacity=10,
            min_after_dequeue=5)
        
    with tf.variable_scope('DNN'):
        logits = architecture(batch_x)
        probabs = tf.nn.softmax(logits)
        
    with tf.name_scope('train'):
        batch_y = tf.cast(batch_y, tf.int32)
        
        loss = tf.losses.sparse_softmax_cross_entropy(labels=batch_y, logits=logits)
        train_op = tf.train.AdamOptimizer().minimize(loss=loss, global_step=tf.train.get_global_step())
        
    with sess.as_default():
        init = [tf.global_variables_initializer(), tf.local_variables_initializer()]
        sess.run(init)
        
        threads = tf.train.start_queue_runners(sess=sess, coord=coord)
        
        for epoch in range(epoch_num):
            loss_sum = 0
            preds = []
            labels = []
            for i in tqdm.trange(n_iterations):               
                _, ls, pred, lab = sess.run([train_op, loss, probabs, batch_y])
                loss_sum += ls
                [preds.append(np.argmax(i)) for i in pred]
                [labels.append(i) for i in lab]

            results = calculate_acc(preds, labels)
            print('Training:')
            print('Accuracy: %.3f \t %i/%i' % (results['acc'], results['sum'], len(y)))
            print('Precision: %.3f \t Recall: %.3f' % (results['precision'], results['recall']))
            
            evaluation = evaluate(X_test, y_test, sess)
            print('\nTest:')
            print('Accuracy: %.3f \t %i/%i' % (evaluation['acc'], evaluation['sum'], len(y_test)))
            print('Precision: %.3f \t Recall: %.3f' % (evaluation['precision'], evaluation['recall']))
            
        coord.request_stop()
        coord.join(threads)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 1440
# 160

# %%
tf.reset_default_graph()
sess = tf.Session()
fit(X_train, y_train, X_test, y_test, 3)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:13<00:00,  1.74it/s]
# Training:
# Accuracy: 0.926 	 1363/1440
# Precision: 0.648 	 Recall: 0.855
#
# Test:
# Accuracy: 0.981 	 157/160
# Precision: 1.000 	 Recall: 0.885
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:16<00:00,  1.42it/s]
# Training:
# Accuracy: 0.994 	 1463/1440
# Precision: 0.989 	 Recall: 0.961
#
# Test:
# Accuracy: 0.994 	 159/160
# Precision: 1.000 	 Recall: 0.962
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:18<00:00,  1.22it/s]
# Training:
# Accuracy: 0.999 	 1471/1440
# Precision: 1.000 	 Recall: 0.994
#
# Test:
# Accuracy: 0.994 	 159/160
# Precision: 1.000 	 Recall: 0.962

# %% [markdown]
# ## Graph exporting

# %%
# writer = tf.summary.FileWriter('logs', sess.graph)
# print(sess.run(logits, feed_dict={features: [X[0]], labels: [y[0]]}))
# writer.close()

# %%
# predictions = sess.run(ar_max, feed_dict={features: X, labels: y})

# conf = confusion_matrix(y, predictions)
# print(conf)

# %% [markdown]
# # Face location

# %%
facefinder = FaceFinder()
patch_size = 100
stride = 2/9

# img = facefinder.process_photo('Faces_test/image_0001.jpg', patch_size=patch_size, stride=stride)[1]
# img1 = facefinder.process_photo('Faces_test/image_0002.jpg', patch_size=patch_size, stride=stride)[1]
# img2 = facefinder.process_photo('Faces_test/image_0003.jpg', patch_size=patch_size, stride=stride)[1]
# img3 = facefinder.process_photo('Faces_test/image_0004.jpg', patch_size=patch_size, stride=stride)[1]
img = facefinder.process_photo(Bush_location+'/George_W_Bush_0145.jpg', patch_size=patch_size, stride=stride)[1]
img1 = facefinder.process_photo(Bush_location+'/George_W_Bush_0141.jpg', patch_size=patch_size, stride=stride)[1]
img2 = facefinder.process_photo(Bush_location+'/George_W_Bush_0143.jpg', patch_size=patch_size, stride=stride)[1]
img3 = facefinder.process_photo(Bush_location+'/George_W_Bush_0151.jpg', patch_size=patch_size, stride=stride)[1]

plt.figure(figsize=(16, 10))
plt.subplot(221)
plt.imshow(img, cmap='gray')
plt.subplot(222)
plt.imshow(img1, cmap='gray')
plt.subplot(223)
plt.imshow(img2, cmap='gray')
plt.subplot(224)
plt.imshow(img3, cmap='gray')
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Patches: 121
# Patches: 121
# Patches: 121
# Patches: 121

# %%
import datetime
name = f"../trained_models/model_{datetime.datetime.today().strftime('%Y-%m-%d_%H-%M')}.ckpt"
saver = tf.train.Saver()
save_path = saver.save(sess, name)
print(f'Saved as {name}')
# Out:
# Saved as ../trained_models/model_2018-05-17_11-31.ckpt

# %%
[print(n.name) for n in tf.get_default_graph().as_graph_def().node]
# Out:
# train_input/Const
# train_input/Const_1
# train_input/shuffle_batch/Const
# train_input/shuffle_batch/random_shuffle_queue
# train_input/shuffle_batch/random_shuffle_queue_EnqueueMany
# train_input/shuffle_batch/random_shuffle_queue_Close
# train_input/shuffle_batch/random_shuffle_queue_Close_1
# train_input/shuffle_batch/random_shuffle_queue_Size
# train_input/shuffle_batch/sub/y
# train_input/shuffle_batch/sub
# train_input/shuffle_batch/Maximum/x
# train_input/shuffle_batch/Maximum
# train_input/shuffle_batch/Cast
# train_input/shuffle_batch/mul/y
# train_input/shuffle_batch/mul
# train_input/shuffle_batch/fraction_over_5_of_5_full/tags
# train_input/shuffle_batch/fraction_over_5_of_5_full
# train_input/shuffle_batch/n
# train_input/shuffle_batch
# output/conv2d/kernel/Initializer/random_uniform/shape
# output/conv2d/kernel/Initializer/random_uniform/min
# output/conv2d/kernel/Initializer/random_uniform/max
# output/conv2d/kernel/Initializer/random_uniform/RandomUniform
# output/conv2d/kernel/Initializer/random_uniform/sub
# output/conv2d/kernel/Initializer/random_uniform/mul
# output/conv2d/kernel/Initializer/random_uniform
# output/conv2d/kernel
# output/conv2d/kernel/Assign
# output/conv2d/kernel/read
# output/conv2d/bias/Initializer/zeros
# output/conv2d/bias
# output/conv2d/bias/Assign
# output/conv2d/bias/read
# output/convolutional/conv2d/convolution/Shape
# output/convolutional/conv2d/convolution/dilation_rate
# output/convolutional/conv2d/convolution
# output/convolutional/conv2d/BiasAdd
# output/convolutional/conv2d/Relu
# output/convolutional/max_pooling2d/MaxPool
# output/conv2d_1/kernel/Initializer/random_uniform/shape
# output/conv2d_1/kernel/Initializer/random_uniform/min
# output/conv2d_1/kernel/Initializer/random_uniform/max
# output/conv2d_1/kernel/Initializer/random_uniform/RandomUniform
# output/conv2d_1/kernel/Initializer/random_uniform/sub
# output/conv2d_1/kernel/Initializer/random_uniform/mul
# output/conv2d_1/kernel/Initializer/random_uniform
# output/conv2d_1/kernel
# output/conv2d_1/kernel/Assign
# output/conv2d_1/kernel/read
# output/conv2d_1/bias/Initializer/zeros
# output/conv2d_1/bias
# output/conv2d_1/bias/Assign
# output/conv2d_1/bias/read
# output/convolutional/conv2d_2/convolution/Shape
# output/convolutional/conv2d_2/convolution/dilation_rate
# output/convolutional/conv2d_2/convolution
# output/convolutional/conv2d_2/BiasAdd
# output/convolutional/conv2d_2/Relu
# output/convolutional/max_pooling2d_2/MaxPool
# output/conv2d_2/kernel/Initializer/random_uniform/shape
# output/conv2d_2/kernel/Initializer/random_uniform/min
# output/conv2d_2/kernel/Initializer/random_uniform/max
# output/conv2d_2/kernel/Initializer/random_uniform/RandomUniform
# output/conv2d_2/kernel/Initializer/random_uniform/sub
# output/conv2d_2/kernel/Initializer/random_uniform/mul
# output/conv2d_2/kernel/Initializer/random_uniform
# output/conv2d_2/kernel
# output/conv2d_2/kernel/Assign
# output/conv2d_2/kernel/read
# output/conv2d_2/bias/Initializer/zeros
# output/conv2d_2/bias
# output/conv2d_2/bias/Assign
# output/conv2d_2/bias/read
# output/convolutional/conv2d_3/convolution/Shape
# output/convolutional/conv2d_3/convolution/dilation_rate
# output/convolutional/conv2d_3/convolution
# output/convolutional/conv2d_3/BiasAdd
# output/convolutional/conv2d_3/Relu
# output/convolutional/max_pooling2d_3/MaxPool
# output/convolutional/Reshape/shape
# output/convolutional/Reshape
# output/dense/kernel/Initializer/random_uniform/shape
# output/dense/kernel/Initializer/random_uniform/min
# output/dense/kernel/Initializer/random_uniform/max
# output/dense/kernel/Initializer/random_uniform/RandomUniform
# output/dense/kernel/Initializer/random_uniform/sub
# output/dense/kernel/Initializer/random_uniform/mul
# output/dense/kernel/Initializer/random_uniform
# output/dense/kernel
# output/dense/kernel/Assign
# output/dense/kernel/read
# output/dense/bias/Initializer/zeros
# output/dense/bias
# output/dense/bias/Assign
# output/dense/bias/read
# output/dense/dense/MatMul
# output/dense/dense/BiasAdd
# output/batch_normalization/beta/Initializer/zeros
# output/batch_normalization/beta
# output/batch_normalization/beta/Assign
# output/batch_normalization/beta/read
# output/batch_normalization/gamma/Initializer/ones
# output/batch_normalization/gamma
# output/batch_normalization/gamma/Assign
# output/batch_normalization/gamma/read
# output/batch_normalization/moving_mean/Initializer/zeros
# output/batch_normalization/moving_mean
# output/batch_normalization/moving_mean/Assign
# output/batch_normalization/moving_mean/read
# output/batch_normalization/moving_variance/Initializer/ones
# output/batch_normalization/moving_variance
# output/batch_normalization/moving_variance/Assign
# output/batch_normalization/moving_variance/read
# output/dense/batch_normalization/moments/Mean/reduction_indices
# output/dense/batch_normalization/moments/Mean
# output/dense/batch_normalization/moments/StopGradient
# output/dense/batch_normalization/moments/Sub
# output/dense/batch_normalization/moments/shifted_mean/reduction_indices
# output/dense/batch_normalization/moments/shifted_mean
# output/dense/batch_normalization/moments/SquaredDifference
# output/dense/batch_normalization/moments/Mean_1/reduction_indices
# output/dense/batch_normalization/moments/Mean_1
# output/dense/batch_normalization/moments/Square
# output/dense/batch_normalization/moments/variance
# output/dense/batch_normalization/moments/mean
# output/dense/batch_normalization/moments/Squeeze
# output/dense/batch_normalization/moments/Squeeze_1
# output/dense/batch_normalization/AssignMovingAvg/decay
# output/dense/batch_normalization/AssignMovingAvg/sub
# output/dense/batch_normalization/AssignMovingAvg/mul
# output/dense/batch_normalization/AssignMovingAvg
# output/dense/batch_normalization/AssignMovingAvg_1/decay
# output/dense/batch_normalization/AssignMovingAvg_1/sub
# output/dense/batch_normalization/AssignMovingAvg_1/mul
# output/dense/batch_normalization/AssignMovingAvg_1
# output/dense/batch_normalization/batchnorm/add/y
# output/dense/batch_normalization/batchnorm/add
# output/dense/batch_normalization/batchnorm/Rsqrt
# output/dense/batch_normalization/batchnorm/mul
# output/dense/batch_normalization/batchnorm/mul_1
# output/dense/batch_normalization/batchnorm/mul_2
# output/dense/batch_normalization/batchnorm/sub
# output/dense/batch_normalization/batchnorm/add_1
# output/dense/Relu
# output/dense_1/kernel/Initializer/random_uniform/shape
# output/dense_1/kernel/Initializer/random_uniform/min
# output/dense_1/kernel/Initializer/random_uniform/max
# output/dense_1/kernel/Initializer/random_uniform/RandomUniform
# output/dense_1/kernel/Initializer/random_uniform/sub
# output/dense_1/kernel/Initializer/random_uniform/mul
# output/dense_1/kernel/Initializer/random_uniform
# output/dense_1/kernel
# output/dense_1/kernel/Assign
# output/dense_1/kernel/read
# output/dense_1/bias/Initializer/zeros
# output/dense_1/bias
# output/dense_1/bias/Assign
# output/dense_3/kernel/Initializer/random_uniform/min
# output/dense_3/kernel/Initializer/random_uniform/max
# output/dense_3/kernel/Initializer/random_uniform/RandomUniform
# output/dense_3/kernel/Initializer/random_uniform/sub
# output/dense_3/kernel/Initializer/random_uniform/mul
# output/dense_3/kernel/Initializer/random_uniform
# output/dense_3/kernel
# output/dense_3/kernel/Assign
# output/dense_3/kernel/read
# output/dense_3/bias/Initializer/zeros
# output/dense_3/bias
# output/dense_3/bias/Assign
# output/dense_3/bias/read
# output/dense/dense_4/MatMul
# output/dense/dense_4/BiasAdd
# output/dense/dense_4/Relu
# output/dense_4/kernel/Initializer/random_uniform/shape
# output/dense_4/kernel/Initializer/random_uniform/min
# output/dense_4/kernel/Initializer/random_uniform/max
# output/dense_4/kernel/Initializer/random_uniform/RandomUniform
# output/dense_4/kernel/Initializer/random_uniform/sub
# output/dense_4/kernel/Initializer/random_uniform/mul
# output/dense_4/kernel/Initializer/random_uniform
# output/dense_4/kernel
# output/dense_4/kernel/Assign
# output/dense_4/kernel/read
# output/dense_4/bias/Initializer/zeros
# output/dense_4/bias
# output/dense_4/bias/Assign
# output/dense_4/bias/read
# output/logits/dense/MatMul
# output/logits/dense/BiasAdd
# output/Softmax
# train/sparse_softmax_cross_entropy_loss/Const
# train/sparse_softmax_cross_entropy_loss/xentropy/Shape
# train/sparse_softmax_cross_entropy_loss/xentropy/xentropy
# train/sparse_softmax_cross_entropy_loss/assert_broadcastable/weights/shape
# train/sparse_softmax_cross_entropy_loss/assert_broadcastable/weights/rank
# train/sparse_softmax_cross_entropy_loss/assert_broadcastable/values/shape
# train/sparse_softmax_cross_entropy_loss/assert_broadcastable/values/rank
# train/sparse_softmax_cross_entropy_loss/assert_broadcastable/static_scalar_check_success
# train/sparse_softmax_cross_entropy_loss/Mul
# train/sparse_softmax_cross_entropy_loss/Const_1
# train/sparse_softmax_cross_entropy_loss/Sum
# train/sparse_softmax_cross_entropy_loss/num_present/Equal/y
# train/sparse_softmax_cross_entropy_loss/num_present/Equal
# train/sparse_softmax_cross_entropy_loss/num_present/zeros_like
# train/sparse_softmax_cross_entropy_loss/num_present/ones_like/Shape
# train/sparse_softmax_cross_entropy_loss/num_present/ones_like/Const
# train/sparse_softmax_cross_entropy_loss/num_present/ones_like
# train/sparse_softmax_cross_entropy_loss/num_present/Select
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/assert_broadcastable/weights/shape
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/assert_broadcastable/weights/rank
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/assert_broadcastable/values/shape
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/assert_broadcastable/values/rank
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/assert_broadcastable/static_scalar_check_success
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/ones_like/Shape
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/ones_like/Const
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights/ones_like
# train/sparse_softmax_cross_entropy_loss/num_present/broadcast_weights
# train/sparse_softmax_cross_entropy_loss/num_present/Const
# train/sparse_softmax_cross_entropy_loss/num_present
# train/sparse_softmax_cross_entropy_loss/Const_2
# train/sparse_softmax_cross_entropy_loss/Sum_1
# train/sparse_softmax_cross_entropy_loss/Greater/y
# train/sparse_softmax_cross_entropy_loss/Greater
# train/sparse_softmax_cross_entropy_loss/Equal/y
# train/sparse_softmax_cross_entropy_loss/Equal
# train/sparse_softmax_cross_entropy_loss/ones_like/Shape
# train/sparse_softmax_cross_entropy_loss/ones_like/Const
# train/sparse_softmax_cross_entropy_loss/ones_like
# train/sparse_softmax_cross_entropy_loss/Select
# train/sparse_softmax_cross_entropy_loss/div
# train/sparse_softmax_cross_entropy_loss/zeros_like
# train/sparse_softmax_cross_entropy_loss/value
# train/gradients/Shape
# train/gradients/Const
# train/gradients/Fill
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/zeros_like
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/Select
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/Select_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/tuple/group_deps
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/tuple/control_dependency
# train/gradients/train/sparse_softmax_cross_entropy_loss/value_grad/tuple/control_dependency_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Shape
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Shape_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/BroadcastGradientArgs
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/RealDiv
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Sum
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Reshape
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Neg
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/RealDiv_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/RealDiv_2
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/mul
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Sum_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/Reshape_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/tuple/group_deps
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/tuple/control_dependency
# train/gradients/train/sparse_softmax_cross_entropy_loss/div_grad/tuple/control_dependency_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_1_grad/Reshape/shape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_1_grad/Reshape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_1_grad/Tile/multiples
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_1_grad/Tile
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_grad/Reshape/shape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_grad/Reshape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_grad/Tile/multiples
# train/gradients/train/sparse_softmax_cross_entropy_loss/Sum_grad/Tile
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Shape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Shape_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/BroadcastGradientArgs
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/mul
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Sum
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Reshape
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/mul_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Sum_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/Reshape_1
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/tuple/group_deps
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/tuple/control_dependency
# train/gradients/train/sparse_softmax_cross_entropy_loss/Mul_grad/tuple/control_dependency_1
# train/gradients/zeros_like
# train/gradients/train/sparse_softmax_cross_entropy_loss/xentropy/xentropy_grad/PreventGradient
# train/gradients/train/sparse_softmax_cross_entropy_loss/xentropy/xentropy_grad/ExpandDims/dim
# train/gradients/train/sparse_softmax_cross_entropy_loss/xentropy/xentropy_grad/ExpandDims
# train/gradients/train/sparse_softmax_cross_entropy_loss/xentropy/xentropy_grad/mul
# train/gradients/output/logits/dense/BiasAdd_grad/BiasAddGrad
# train/gradients/output/logits/dense/BiasAdd_grad/tuple/group_deps
# train/gradients/output/logits/dense/BiasAdd_grad/tuple/control_dependency
# train/gradients/output/logits/dense/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/output/logits/dense/MatMul_grad/MatMul
# train/gradients/output/logits/dense/MatMul_grad/MatMul_1
# train/gradients/output/logits/dense/MatMul_grad/tuple/group_deps
# train/gradients/output/logits/dense/MatMul_grad/tuple/control_dependency
# train/gradients/output/logits/dense/MatMul_grad/tuple/control_dependency_1
# train/gradients/output/dense/dense_4/Relu_grad/ReluGrad
# train/gradients/output/dense/dense_4/BiasAdd_grad/BiasAddGrad
# train/gradients/output/dense/dense_4/BiasAdd_grad/tuple/group_deps
# train/gradients/output/dense/dense_4/BiasAdd_grad/tuple/control_dependency
# train/gradients/output/dense/dense_4/BiasAdd_grad/tuple/control_dependency_1
# train/gradients/output/dense/dense_4/MatMul_grad/MatMul
# train/gradients/output/dense/dense_4/MatMul_grad/MatMul_1
# train/gradients/output/dense/dense_4/MatMul_grad/tuple/group_deps
# train/gradients/output/dense/dense_4/MatMul_grad/tuple/control_dependency
# train/gradients/output/dense/dense_4/MatMul_grad/tuple/control_dependency_1
# train/gradients/output/dense/Relu_1_grad/ReluGrad
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Sum
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/mul
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Sum
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/mul_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Sum
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Neg
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/mul
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Sum
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/mul_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/moments/Squeeze_grad/Shape
# train/gradients/output/dense/batch_normalization_2/moments/Squeeze_grad/Reshape
# train/gradients/AddN
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/mul
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Sum
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/mul_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Shape
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Sum
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Reshape
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Sum_1
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/Reshape_1
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization_2/moments/mean_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_grad/Shape
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_grad/Shape_1
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization_2/batchnorm/add_grad/Sum
# train/gradients/output/dense/dense_2/MatMul_grad/MatMul_1
# train/gradients/output/dense/dense_2/MatMul_grad/tuple/group_deps
# train/gradients/output/dense/dense_2/MatMul_grad/tuple/control_dependency
# train/gradients/output/dense/dense_2/MatMul_grad/tuple/control_dependency_1
# train/gradients/output/dense/Relu_grad/ReluGrad
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Sum
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Reshape
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Sum_1
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/batchnorm/add_1_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/mul
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Sum
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Reshape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/mul_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Sum_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/batchnorm/mul_1_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Sum
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Reshape
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Sum_1
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Neg
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/batchnorm/sub_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/mul
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Sum
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Reshape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/mul_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Sum_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/batchnorm/mul_2_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/moments/Squeeze_grad/Shape
# train/gradients/output/dense/batch_normalization/moments/Squeeze_grad/Reshape
# train/gradients/AddN_4
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/mul
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Sum
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Reshape
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/mul_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Sum_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/batchnorm/mul_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Shape
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Shape_1
# train/gradients/output/dense/batch_normalization/moments/mean_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Sum
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Reshape
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Sum_1
# train/gradients/output/dense/batch_normalization/moments/mean_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/moments/mean_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/moments/mean_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/moments/mean_grad/tuple/control_dependency_1
# train/gradients/output/dense/batch_normalization/batchnorm/Rsqrt_grad/RsqrtGrad
# train/gradients/output/dense/batch_normalization/batchnorm/add_grad/Shape
# train/gradients/output/dense/batch_normalization/batchnorm/add_grad/Shape_1
# train/gradients/output/dense/batch_normalization/batchnorm/add_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/batchnorm/add_grad/Sum
# train/gradients/output/dense/batch_normalization/moments/Mean_1_grad/Maximum_1
# train/gradients/output/dense/batch_normalization/moments/Mean_1_grad/floordiv_1
# train/gradients/output/dense/batch_normalization/moments/Mean_1_grad/Cast
# train/gradients/output/dense/batch_normalization/moments/Mean_1_grad/truediv
# train/gradients/output/dense/batch_normalization/moments/Square_grad/mul/x
# train/gradients/output/dense/batch_normalization/moments/Square_grad/mul
# train/gradients/output/dense/batch_normalization/moments/Square_grad/mul_1
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Shape
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Shape_1
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/BroadcastGradientArgs
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/scalar
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/mul
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/sub
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/mul_1
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Sum
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Reshape
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Sum_1
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Reshape_1
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/Neg
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/tuple/group_deps
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency
# train/gradients/output/dense/batch_normalization/moments/SquaredDifference_grad/tuple/control_dependency_1
# train/gradients/AddN_5
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Shape
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Size
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/add
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/mod
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Shape_1
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/range/start
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/range/delta
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/range
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Fill/value
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Fill
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/DynamicStitch
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Maximum/y
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Maximum
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/floordiv
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Reshape
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Tile
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Shape_2
# train/gradients/output/dense/batch_normalization/moments/shifted_mean_grad/Shape_3
# save/RestoreV2_2/tensor_names
# save/RestoreV2_2/shape_and_slices
# save/RestoreV2_2
# save/Assign_2
# save/RestoreV2_3/tensor_names
# save/RestoreV2_3/shape_and_slices
# save/RestoreV2_3
# save/Assign_3
# save/RestoreV2_4/tensor_names
# save/RestoreV2_4/shape_and_slices
# save/RestoreV2_4
# save/Assign_4
# save/RestoreV2_5/tensor_names
# save/RestoreV2_5/shape_and_slices
# save/RestoreV2_5
# save/Assign_5
# save/RestoreV2_6/tensor_names
# save/RestoreV2_6/shape_and_slices
# save/RestoreV2_6
# save/Assign_6
# save/RestoreV2_7/tensor_names
# save/RestoreV2_7/shape_and_slices
# save/RestoreV2_7
# save/Assign_7
# save/RestoreV2_8/tensor_names
# save/RestoreV2_8/shape_and_slices
# save/RestoreV2_8
# save/Assign_8
# save/RestoreV2_9/tensor_names
# save/RestoreV2_9/shape_and_slices
# save/RestoreV2_9
# save/Assign_9
# save/RestoreV2_10/tensor_names
# save/RestoreV2_10/shape_and_slices
# save/RestoreV2_10
# save/Assign_10
# save/RestoreV2_11/tensor_names
# save/RestoreV2_11/shape_and_slices
# save/RestoreV2_11
# save/Assign_11
# save/RestoreV2_12/tensor_names
# save/RestoreV2_12/shape_and_slices
# save/RestoreV2_12
# save/Assign_12
# save/RestoreV2_13/tensor_names
# save/RestoreV2_13/shape_and_slices
# save/RestoreV2_13
# save/Assign_13
# save/RestoreV2_14/tensor_names
# save/RestoreV2_14/shape_and_slices
# save/RestoreV2_14
# save/Assign_14
# save/RestoreV2_15/tensor_names
# save/RestoreV2_15/shape_and_slices
# save/RestoreV2_15
# save/Assign_15
# save/RestoreV2_16/tensor_names
# save/RestoreV2_16/shape_and_slices
# save/RestoreV2_16
# save/Assign_16
# save/RestoreV2_17/tensor_names
# save/RestoreV2_17/shape_and_slices
# save/RestoreV2_17
# save/Assign_17
# save/RestoreV2_18/tensor_names
# save/RestoreV2_18/shape_and_slices
# save/RestoreV2_18
# save/Assign_18
# save/RestoreV2_19/tensor_names
# save/RestoreV2_19/shape_and_slices
# save/RestoreV2_19
# save/Assign_19
# save/RestoreV2_20/tensor_names
# save/RestoreV2_20/shape_and_slices
# save/RestoreV2_20
# save/Assign_20
# save/RestoreV2_21/tensor_names
# save/RestoreV2_21/shape_and_slices
# save/RestoreV2_21
# save/Assign_21
# save/RestoreV2_22/tensor_names
# save/RestoreV2_22/shape_and_slices
# save/RestoreV2_22
# save/Assign_22
# save/RestoreV2_23/tensor_names
# save/RestoreV2_23/shape_and_slices
# save/RestoreV2_23
# save/Assign_23
# save/RestoreV2_24/tensor_names
# save/RestoreV2_24/shape_and_slices
# save/RestoreV2_24
# save/Assign_24
# save/RestoreV2_25/tensor_names
# save/RestoreV2_25/shape_and_slices
# save/RestoreV2_25
# save/Assign_25
# save/RestoreV2_26/tensor_names
# save/RestoreV2_26/shape_and_slices
# save/RestoreV2_26
# save/Assign_26
# save/RestoreV2_27/tensor_names
# save/RestoreV2_27/shape_and_slices
# save/RestoreV2_27
# save/Assign_27
# save/RestoreV2_28/tensor_names
# save/RestoreV2_28/shape_and_slices
# save/RestoreV2_28
# save/Assign_28
# save/RestoreV2_29/tensor_names
# save/RestoreV2_29/shape_and_slices
# save/RestoreV2_29
# save/Assign_29
# save/RestoreV2_30/tensor_names
# save/RestoreV2_30/shape_and_slices
# save/RestoreV2_30
# save/Assign_30
# save/RestoreV2_31/tensor_names
# save/RestoreV2_31/shape_and_slices
# save/RestoreV2_31
# save/Assign_31
# save/RestoreV2_32/tensor_names
# save/RestoreV2_32/shape_and_slices
# save/RestoreV2_32
# save/Assign_32
# save/RestoreV2_33/tensor_names
# save/RestoreV2_33/shape_and_slices
# save/RestoreV2_33
# save/Assign_33
# save/RestoreV2_34/tensor_names
# save/RestoreV2_34/shape_and_slices
# save/RestoreV2_34
# save/Assign_34
# save/RestoreV2_35/tensor_names
# save/RestoreV2_35/shape_and_slices
# save/RestoreV2_35
# save/Assign_35
# save/RestoreV2_36/tensor_names
# save/RestoreV2_36/shape_and_slices
# save/RestoreV2_36
# save/Assign_36
# save/RestoreV2_37/tensor_names
# save/RestoreV2_37/shape_and_slices
# save/RestoreV2_37
# save/Assign_37
# save/RestoreV2_38/tensor_names
# save/RestoreV2_38/shape_and_slices
# save/RestoreV2_38
# save/Assign_38
# save/RestoreV2_39/tensor_names
# save/RestoreV2_39/shape_and_slices
# save/RestoreV2_39
# save/Assign_39
# save/RestoreV2_40/tensor_names
# save/RestoreV2_40/shape_and_slices
# save/RestoreV2_40
# save/Assign_40
# save/RestoreV2_41/tensor_names
# save/RestoreV2_41/shape_and_slices
# save/RestoreV2_41
# save/Assign_41
# save/RestoreV2_42/tensor_names
# save/RestoreV2_42/shape_and_slices
# save/RestoreV2_42
# save/Assign_42
# save/RestoreV2_43/tensor_names
# save/RestoreV2_43/shape_and_slices
# save/RestoreV2_43
# save/Assign_43
# save/RestoreV2_44/tensor_names
# save/RestoreV2_44/shape_and_slices
# save/RestoreV2_44
# save/Assign_44
# save/RestoreV2_45/tensor_names
# save/RestoreV2_45/shape_and_slices
# save/RestoreV2_45
# save/Assign_45
# save/RestoreV2_46/tensor_names
# save/RestoreV2_46/shape_and_slices
# save/RestoreV2_46
# save/Assign_46
# save/RestoreV2_47/tensor_names
# save/RestoreV2_47/shape_and_slices
# save/RestoreV2_47
# save/Assign_47
# save/RestoreV2_48/tensor_names
# save/RestoreV2_48/shape_and_slices
# save/RestoreV2_48
# save/Assign_48
# save/RestoreV2_49/tensor_names
# save/RestoreV2_49/shape_and_slices
# save/RestoreV2_49
# save/Assign_49
# save/RestoreV2_50/tensor_names
# save/RestoreV2_50/shape_and_slices
# save/RestoreV2_50
# save/Assign_50
# save/RestoreV2_51/tensor_names
# save/RestoreV2_51/shape_and_slices
# save/RestoreV2_51
# save/Assign_51
# save/RestoreV2_52/tensor_names
# save/RestoreV2_52/shape_and_slices
# save/RestoreV2_52
# save/Assign_52
# save/RestoreV2_53/tensor_names
# save/RestoreV2_53/shape_and_slices
# save/RestoreV2_53
# save/Assign_53
# save/RestoreV2_54/tensor_names
# save/RestoreV2_54/shape_and_slices
# save/RestoreV2_54
# save/Assign_54
# save/RestoreV2_55/tensor_names
# save/RestoreV2_55/shape_and_slices
# save/RestoreV2_55
# save/Assign_55
# save/RestoreV2_56/tensor_names
# save/RestoreV2_56/shape_and_slices
# save/RestoreV2_56
# save/Assign_56
# save/RestoreV2_57/tensor_names
# save/RestoreV2_57/shape_and_slices
# save/RestoreV2_57
# save/Assign_57
# save/RestoreV2_58/tensor_names
# save/RestoreV2_58/shape_and_slices
# save/RestoreV2_58
# save/Assign_58
# save/RestoreV2_59/tensor_names
# save/RestoreV2_59/shape_and_slices
# save/RestoreV2_59
# save/Assign_59
# save/RestoreV2_60/tensor_names
# save/RestoreV2_60/shape_and_slices
# save/RestoreV2_60
# save/Assign_60
# save/RestoreV2_61/tensor_names
# save/RestoreV2_61/shape_and_slices
# save/RestoreV2_61
# save/Assign_61
# save/RestoreV2_62/tensor_names
# save/RestoreV2_62/shape_and_slices
# save/RestoreV2_62
# save/Assign_62
# save/RestoreV2_63/tensor_names
# save/RestoreV2_63/shape_and_slices
# save/RestoreV2_63
# save/Assign_63
# save/RestoreV2_64/tensor_names
# save/RestoreV2_64/shape_and_slices
# save/RestoreV2_64
# save/Assign_64
# save/RestoreV2_65/tensor_names
# save/RestoreV2_65/shape_and_slices
# save/RestoreV2_65
# save/Assign_65
# save/restore_all
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    from tensorflow.python.framework.graph_util import convert_variables_to_constants
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = convert_variables_to_constants(session, input_graph_def,
                                                      output_names, freeze_var_names)
        return frozen_graph

# %%
frozen_graph = freeze_session(keras.backend.get_session(), output_names=[model.output.op.name])

# %%
tf.train.write_graph(frozen_graph, "frozen_model", "model.pb", as_text=False)

# %% [markdown]
# checkpoint = tf.train.get_checkpoint_state('./frozen/')
# input_checkpoint = checkpoint.model_checkpoint_path
#
# absolute_model_dir = "/".join(input_checkpoint.split('/')[:-1])
# output_graph = absolute_model_dir + "/frozen_model.pb"
#
# clear_devices = True
#
# with tf.Session(graph=tf.Graph()) as sess:
#     saver = tf.train.import_meta_graph(input_checkpoint + '.meta', clear_devices=clear_devices)
#
#     saver.restore(sess, input_checkpoint)
#
#     output_graph_def = tf.graph_util.convert_variables_to_constants(
#         sess,
#         tf.get_default_graph().as_graph_def(),
#         ['activation_7/Softmax']
#     )
#
#     with tf.gfile.GFile(output_graph, "wb") as f:
#         f.write(output_graph_def.SerializeToString())
#     print("%d ops in the final graph." % len(output_graph_def.node))
